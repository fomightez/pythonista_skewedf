# %% [markdown]
# # Testing `SkeweDF::Exponential()` in R
#
# Load the **SkeweDF** package

# %%
library(SkeweDF)

# %% [markdown]
# --------
#
#
# Examples of use and results:

# %%
SkeweDF::Exponential(20, 3000, 0.8)
# Out:
#  [1] 1.347987e+03 6.056896e+02 2.721539e+02 1.222866e+02 5.494692e+01
#  [6] 2.468924e+01 1.109359e+01 4.984672e+00 2.239757e+00 1.006388e+00
# [11] 4.521992e-01 2.031862e-01 9.129745e-02 4.102259e-02 1.843264e-02
# [16] 8.282318e-03 3.721485e-03 1.672171e-03 7.513549e-04 3.376055e-04

# %%
SkeweDF::Exponential(20, 100, 0.6)
# Out:
#  [1] 5.488116e+01 3.011942e+01 1.652989e+01 9.071795e+00 4.978707e+00
#  [6] 2.732372e+00 1.499558e+00 8.229747e-01 4.516581e-01 2.478752e-01
# [11] 1.360368e-01 7.465858e-02 4.097350e-02 2.248673e-02 1.234098e-02
# [16] 6.772874e-03 3.717032e-03 2.039950e-03 1.119548e-03 6.144212e-04

# %%
SkeweDF::Exponential(25, 200, 0.7)
# Out:
#  [1] 9.931706e+01 4.931939e+01 2.449129e+01 1.216201e+01 6.039477e+00
#  [6] 2.999115e+00 1.489317e+00 7.395727e-01 3.672610e-01 1.823764e-01
# [11] 9.056544e-02 4.497346e-02 2.233316e-02 1.109032e-02 5.507290e-03
# [16] 2.734839e-03 1.358081e-03 6.744030e-04 3.348986e-04 1.663057e-04
# [21] 8.258499e-05 4.101049e-05 2.036521e-05 1.011306e-05 5.021998e-06
